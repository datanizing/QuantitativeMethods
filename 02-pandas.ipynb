# %%
import pandas as pd

# %%
import eurostat

# %%
cp = eurostat.get_data_df("EI_CPHI_M")

# %%
cp
# Out:
#      freq      unit s_adj    indic geo\TIME_PERIOD  1996-01  1996-02  1996-03  \
# 0       M  HICP2015   NSA  CP-HI00              AT    71.34    71.55    71.77
# 1       M  HICP2015   NSA  CP-HI00              BE    69.91    69.98    70.12
# 2       M  HICP2015   NSA  CP-HI00              BG      NaN      NaN      NaN
# 3       M  HICP2015   NSA  CP-HI00              CH      NaN      NaN      NaN
# 4       M  HICP2015   NSA  CP-HI00              CY    66.48    64.45    66.46
# ...   ...       ...   ...      ...             ...      ...      ...      ...
# 3034    M      RT12   NSA   CP-HIS              SE      NaN      NaN      NaN
# 3035    M      RT12   NSA   CP-HIS              SI      NaN      NaN      NaN
# 3036    M      RT12   NSA   CP-HIS              SK      NaN      NaN      NaN
# 3037    M      RT12   NSA   CP-HIS              TR      NaN      NaN      NaN
# 3038    M      RT12   NSA   CP-HIS              UK      NaN      NaN      NaN
#
# ...

# %%
cp[cp.index>=3036]

# %%
# loc
cp.loc[3036:3038]

# %%
# group
cg = cp.groupby(["indic", "unit"]).count()
cg

# %%
cg.loc["CP-HIS"]

# %%
cg.loc["CP-HIS"].plot()

# %%
cg.iloc[-1]

# %%
cg.iloc[0]
